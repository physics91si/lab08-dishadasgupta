# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1

# %% [markdown]
# data = np.loadtxt("droptower_vdata.txt")
#
# time = []
# velocity = []
#
# for x in data:
#     time.append(x[0])
#     velocity.append(x[1])
#
# acceleration = []
# for i in range(len(velocity)):
#     acceleration.append((velocity[i] - velocity[i-1])/(time[i] - time[i-1]))
#
# position = integrate.cumtrapz(velocity, initial = 0)

# %%
plt.plot(time, position, label = "Position")
plt.plot(time, velocity, label = "Velocity")
plt.plot(time, acceleration, label = "Acceleration")
plt.legend()
plt.xlabel('Time')
# Out:
# Text(0.5,0,'Time')

# %% [markdown]
# ## Part 2

# %%
acceleration = np.asarray(acceleration)
newacc = acceleration[np.where(acceleration>0)]

avgacc = np.mean(newacc)

print("Average Positive Acceleration: " + str(avgacc))
# Out:
# Average Positive Acceleration: 7.5600000000000005
